# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Отлично, Дмитрий! Ты исправил все значительные недостатки и теперь твой проект конечно же принят. Однако, я всё же отправлю проект тебе ещё раз, вдруг ты захочешь в него добавить что-то еще или просто взглянуть на него. Когда решишь, что ты готов закончить проект, просто отправь мне его и я его сразу приму.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента v 2.0:</b> Дмитрий, спасибо за крутую обратную связь по проекту. Я взглянул на проект, решил, что не буду ничего менять, но пометил, на какие моменты обратить внимание в будущем. Еще раз спасибо)</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 3.0 ✔️:</b> Проект принят. Спасибо за работу!)

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# <b>Привет!</b>
#
# Меня зовут Михаленко Дмитрий, и я буду проверять твой проект. Предлагаю общаться на «ты» :) Но если это не удобно - дай знать, и мы перейдем на "вы".
#
# Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных. Ты уже проделал большую работу над проектом, но давай сделаем его еще лучше. Ниже ты найдешь мои комментарии - **пожалуйста, не перемещай, не изменяй и не удаляй их**. Увидев у тебя ошибку, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой начальник будет поступать так же, а я пытаюсь подготовить тебя именно к работе аналитиком. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger">
# <b>Комментарий ревьюера ❌:</b> Так выделены самые важные замечания. Без их отработки проект не будет принят. </div>
#
# <div class="alert alert-warning">
# <b>Комментарий ревьюера ⚠️:</b> Так выделены небольшие замечания. Я надеюсь, что их ты тоже учтешь - твой проект от этого станет только лучше. Но настаивать на их отработке не буду.
#
# </div>
#
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Так я выделяю все остальные комментарии.</div>
#
# Давай работать над проектом в диалоге: **если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом.** Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# Целью данной работы является исследование зависимости цены квартир от различных факторов.
# Задачи:
# 1. Разобраться с вводными данными
# 2. Сделать предобратку данных и подготовить данные к исследованию
# 3. Произвести анализ данных
# 4. Сделать выводы по результатам

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Интересная аналитическая задача, посмотрим, что же нужно сделать для ее решения. </div>

# %% [markdown]
# ## Изучение данных из файла

# %%
import pandas as pd

# %%
df = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %%
display(df.head(50))
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1              7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2             10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3              0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4              2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6              6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7              5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9             18   5400000.0       61.00  2017-02-26T00:00:00      3
# 10             5   5050000.0       39.60  2017-11-16T00:00:00      1
# 11             9   3300000.0       44.00  2018-08-27T00:00:00      2
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Первые выводы:
# 1. 22 столбца, 23699 строк. Больше чем в половине столбцов есть пропуски.
# 2. Столбец ceiling_height интересен тем, что не везде указана высота потолков, но для большинства жилых помещений высота потолков примерно одинакова и пропуски можно заменить медианой.
# 3. Пропуски в столбце living_area заменить вряд ли получится, так как нужны точные данные. Однако пропусков не так критично много, общая доля пропусков составляет порядка 8-9 % от всей таблицы, возможно, придется удалить строки. Или можно взять медианные значения для пропусков в зависимости от кол-ва комнат в квартирах.
# 4. Примерно такие же выводы можно сделать для столбца kitchen_area.
# 5. is_apartment по идее должен быть булевым столбцом. Пропуски скорее всего в местах, где вместо 1 стоит 0.
# 6. balcony пропуски в местах, где скорее всего нет балконов, и можно сделать замену на 0.
# 7. locality_name - нужны точные данные. Удалить/оставить.
# 8. Столбцы типа airports_nearest, cityCenters_nearest и т.д., которые содержат расстояния до каких-либо мест имеют пропуски, но они для тех мест, где в принципе поблизости ничего нет, например, поселки. То есть расстояние в таких местах очень большое до данных мест. Заменить на ноль нельзя, возможно, стоит оставить пропуски, либо заменить на значения превышающие максимальные.
# 9. days_exposition можно определить сколько дней находятся объявления на площадке, если узнать дату изъятия БД.
# 10. Также у части данных можно заменить тип на целочисленный, т.к. десятые доли незначительны. Наример, цена или количество метров. И в столбце is-apartment нужно поправить тип на булевый.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Хорошее начало и первый промежуточный вывод, так держать. </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера ⚠️:</b> В days_exposition еще неплохо было бы посмотреть на пропуски по годам, вдруг так тоже можно увидеть какую-то закономерность

# %% [markdown]
# ## Предобработка данных

# %%
df['ceiling_height'] = df['ceiling_height'].fillna(df['ceiling_height'].median())

# %%
display(df['ceiling_height'].head())
# Out:
# 0    2.70
# 1    2.65
# 2    2.65
# 3    2.65
# 4    3.03
# Name: ceiling_height, dtype: float64

# %%
print(len(df.query('ceiling_height > 3.5')))
# Out:
# 304

# %%
display(df.query('(ceiling_height > 3.5) or (ceiling_height < 2.4)').head(50)) #аномально большие и маленькие значения можно попробовать заменить на среднее или стандартное значение
# Out:
#       total_images   last_price  total_area first_day_exposition  rooms  \
# 154              1    8200000.0        80.0  2018-11-06T00:00:00      3
# 179              5   14800000.0       108.7  2019-04-11T00:00:00      3
# 227             13    2200000.0        47.0  2018-01-12T00:00:00      3
# 355             17    3600000.0        55.2  2018-07-12T00:00:00      2
# 368             19   12500000.0        85.0  2018-09-21T00:00:00      3
# 464             15   66571000.0       280.3  2015-06-11T00:00:00      6
# 552             11    2999000.0        33.5  2017-03-30T00:00:00      1
# 635             17   25990000.0       133.9  2018-03-16T00:00:00      4
# 797              1    7500800.0       105.2  2017-09-08T00:00:00      3
# 807             14   18777000.0       181.5  2018-07-25T00:00:00      6
# 836             20   13500000.0        78.7  2016-04-13T00:00:00      3
# 885              9    8200000.0        96.0  2018-07-23T00:00:00      3
# ...

# %%
def height(ceiling_height):
    if ceiling_height > 3.5:
        ceiling_height = 3
        return ceiling_height
    elif ceiling_height < 2.4:
        ceiling_height = 3
        return ceiling_height
    else:
        return ceiling_height

# %%
df['ceiling_height'] = df['ceiling_height'].apply(height)

# %%
print(df['ceiling_height'].tail(10))
# Out:
# 23689    2.86
# 23690    2.65
# 23691    2.75
# 23692    2.65
# 23693    2.60
# 23694    3.00
# 23695    2.65
# 23696    2.65
# 23697    3.00
# 23698    2.50
# Name: ceiling_height, dtype: float64

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера ❌:</b> Сами решения хорошие, но стоит обосновать, почему в функции были выбраны границы именно 2.4 и 3.5 метра, а не какие-то другие

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Я взял данные значения, т.к. примерно в этом диапазоне находятся минимальное и максимальное значение потолков в среднем для квартир, просто посмотрел в интернете. Поэтому все что ниже этой отметки решил приравнять к минимуму, а все больше приравнять к максимальному значению.</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Ок, логичное обоснование </div>

# %%
df['balcony'] = df['balcony'].fillna(0)

# %%
df['balcony'] = df['balcony'].astype('int')

# %%
print(df['balcony'].head())
# Out:
# 0    0
# 1    2
# 2    0
# 3    0
# 4    0
# Name: balcony, dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Нули здесь подойдут

# %%
print(df['floors_total'].describe()) # есть пропуски, но не получится заменить их и поменять тип данных.
# Out:
# count    23613.000000
# mean        10.673824
# std          6.597173
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %%
df['is_apartment'] = df['is_apartment'].fillna(False)

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Хорошо

# %%
print(df['is_apartment'].head(20))
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: is_apartment, dtype: bool

# %%
df['is_apartment'] = df['is_apartment'].astype('bool')

# %%
print(df['first_day_exposition'].describe())
# Out:
# count                   23699
# unique                   1491
# top       2018-02-01T00:00:00
# freq                      368
# Name: first_day_exposition, dtype: object

# %%
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Это изменение еще пригодится

# %%
print(df['first_day_exposition'].head())
# Out:
# 0   2019-03-07
# 1   2018-12-04
# 2   2015-08-20
# 3   2015-07-24
# 4   2018-06-19
# Name: first_day_exposition, dtype: datetime64[ns]

# %%
print(df['last_price'].head())
# Out:
# 0    13000000.0
# 1     3350000.0
# 2     5196000.0
# 3    64900000.0
# 4    10000000.0
# Name: last_price, dtype: float64

# %%
df['last_price'] = df['last_price'].astype('int')

# %%
print(df['last_price'].head())
# Out:
# 0    13000000
# 1     3350000
# 2     5196000
# 3    64900000
# 4    10000000
# Name: last_price, dtype: int64

# %%
print(df['locality_name'].unique())
# Out:
# ['Санкт-Петербург' 'посёлок Шушары' 'городской посёлок Янино-1'
#  'посёлок Парголово' 'посёлок Мурино' 'Ломоносов' 'Сертолово' 'Петергоф'
#  'Пушкин' 'деревня Кудрово' 'Коммунар' 'Колпино'
#  'поселок городского типа Красный Бор' 'Гатчина' 'поселок Мурино'
#  'деревня Фёдоровское' 'Выборг' 'Кронштадт' 'Кировск'
#  'деревня Новое Девяткино' 'посёлок Металлострой'
#  'посёлок городского типа Лебяжье' 'посёлок городского типа Сиверский'
#  'поселок Молодцово' 'поселок городского типа Кузьмоловский'
#  'садовое товарищество Новая Ропша' 'Павловск' 'деревня Пикколово'
#  'Всеволожск' 'Волхов' 'Кингисепп' 'Приозерск' 'Сестрорецк'
#  'деревня Куттузи' 'посёлок Аннино' 'поселок городского типа Ефимовский'
#  'посёлок Плодовое' 'деревня Заклинье' 'поселок Торковичи'
#  'поселок Первомайское' 'Красное Село' 'посёлок Понтонный' 'Сясьстрой'
#  'деревня Старая' 'деревня Лесколово' 'посёлок Новый Свет' 'Сланцы'
#  'село Путилово' 'Ивангород' 'Мурино' 'Шлиссельбург' 'Никольское'
# ...

# %%
display(df.groupby('locality_name').count().sort_values(by='last_price', ascending=False).head(20))
# Out:
#                          total_images  last_price  total_area  \
# locality_name
# Санкт-Петербург                 15721       15721       15721
# посёлок Мурино                    522         522         522
# посёлок Шушары                    440         440         440
# Всеволожск                        398         398         398
# Пушкин                            369         369         369
# Колпино                           338         338         338
# посёлок Парголово                 327         327         327
# Гатчина                           307         307         307
# деревня Кудрово                   299         299         299
# Выборг                            237         237         237
# Петергоф                          201         201         201
# Сестрорецк                        183         183         183
# Красное Село                      178         178         178
# Кудрово                           173         173         173
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера ⚠️:</b> Еще хорошо было бы проверить на неявные дубликаты

# %% [markdown]
# Хотел посмотреть повторы по тексту и какой регистр используется. В целом все в порядке. Посмотрел популярность мест. Самый популярный Питер с самым большим количеством предложений.

# %% [markdown]
# Часть пропусков были заменены и исправлены значения типой данных в столбцаз, где нет пропусков. В некоторых столбцах принял решение не менять пропуски и не удалять их, так как это может повлиять негативно на результат.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Отлично, промежуточный вывод тоже здесь обозначен

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %%
df['price_for_metr'] = df['last_price']/df['total_area']

# %%
print(df['floor'].unique())
# Out:
# [ 8  1  4  9 13  5  6 22 26  7  3  2 11 15 18 10 19 16 20 27 25 17 14 12
#  21 28 24 23 30 29 32 33 31]

# %% [markdown]
# Для дня недели, месяца и года столбец был сделан в предыдущем этапе.

# %%
df['weekday'] = df['first_day_exposition'].dt.weekday

# %%
print(df['weekday'])
# Out:
# 0        3
# 1        1
# 2        3
# 3        4
# 4        1
#         ..
# 23694    1
# 23695    0
# 23696    6
# 23697    1
# 23698    4
# Name: weekday, Length: 23699, dtype: int64

# %%
df['month'] = df['first_day_exposition'].dt.month

# %%
print(df['month'])
# Out:
# 0         3
# 1        12
# 2         8
# 3         7
# 4         6
#          ..
# 23694     3
# 23695     1
# 23696     2
# 23697     3
# 23698     7
# Name: month, Length: 23699, dtype: int64

# %%
df['year'] = df['first_day_exposition'].dt.year

# %%
print(df['year'])
# Out:
# 0        2019
# 1        2018
# 2        2015
# 3        2015
# 4        2018
#          ...
# 23694    2017
# 23695    2018
# 23696    2018
# 23697    2017
# 23698    2017
# Name: year, Length: 23699, dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Рабочая функция

# %%
def category_floor(row):
    x = row['floor']
    y = row['floors_total']
    if x==1:
        return 'первый' 
    elif x == y:
        return 'последний'  
    return 'другой'

# %%
df['category_floor'] = df.apply(category_floor, axis=1)

# %%
print(df.groupby('category_floor').count())
# Out:
#                 total_images  last_price  total_area  first_day_exposition  \
# category_floor
# другой                 17446       17446       17446                 17446
# первый                  2917        2917        2917                  2917
# последний               3336        3336        3336                  3336
#
#                 rooms  ceiling_height  floors_total  living_area  floor  \
# category_floor
# другой          17446           17446         17363        16049  17446
# первый           2917            2917          2914         2664   2917
# последний        3336            3336          3336         3083   3336
#
#                 is_apartment  ...  cityCenters_nearest  parks_around3000  \
# category_floor                ...
# другой                 17446  ...                13850             13851
# первый                  2917  ...                 1999              1999
# последний               3336  ...                 2331              2331
#
# ...

# %%
print(df.head(10))
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000      108.00           2019-03-07      3
# 1             7     3350000       40.40           2018-12-04      1
# 2            10     5196000       56.00           2015-08-20      2
# 3             0    64900000      159.00           2015-07-24      3
# 4             2    10000000      100.00           2018-06-19      2
# 5            10     2890000       30.40           2018-09-10      1
# 6             6     3700000       37.30           2017-11-02      1
# 7             5     7915000       71.60           2019-04-18      2
# 8            20     2900000       33.16           2018-05-23      1
# 9            18     5400000       61.00           2017-02-26      3
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70          16.0        51.00      8         False  ...
# 1            2.65          11.0        18.60      1         False  ...
# ...

# %%
df['living_and_total_area_relation'] = df['living_area']/df['total_area']

# %%
df['kitchen_and_total_area_relation'] = df['kitchen_area']/df['total_area']

# %%
display(df.head(10))
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000      108.00           2019-03-07      3
# 1             7     3350000       40.40           2018-12-04      1
# 2            10     5196000       56.00           2015-08-20      2
# 3             0    64900000      159.00           2015-07-24      3
# 4             2    10000000      100.00           2018-06-19      2
# 5            10     2890000       30.40           2018-09-10      1
# 6             6     3700000       37.30           2017-11-02      1
# 7             5     7915000       71.60           2019-04-18      2
# 8            20     2900000       33.16           2018-05-23      1
# 9            18     5400000       61.00           2017-02-26      3
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70          16.0        51.00      8         False  ...
# 1            2.65          11.0        18.60      1         False  ...
# ...

# %% [markdown]
# Все необходимые данные посчитаны. Можно переходить к исследовательскому анализу данных.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Великолепно, все пункты задания выполнены в полном объёме

# %% [markdown]
# ## Исследовательский анализ данных

# %%
df['total_area'].hist(bins=100, range=(0, 470))
# Out:
# <AxesSubplot:>

# %%
df['total_area'].hist(bins=100, range=(0, 100))
# Out:
# <AxesSubplot:>

# %%
df['last_price'].hist(bins=100, range=(0, 80000000))
# Out:
# <AxesSubplot:>

# %%
df['last_price'].hist(bins=100, range=(0, 10000000))
# Out:
# <AxesSubplot:>

# %%
df['last_price'].hist(bins=100, range=(0, 100000))
# Out:
# <AxesSubplot:>

# %%
df['ceiling_height'].hist(bins=50, range=(2, 5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Для каждого из параметров можно сделать вывод, что распределние отличается от нормального. Площадь в целом сосредоточена в районе примерно 50 квадратов и ниже. Есть пики по количеству в районе 30, 50, 60 и 80 квадратов. Я преполагаю, что это связано со стандартной площадью для определенных типов квартир. Есть и квартиры с квадратурой больше 100 метров, но это скорее редкость, чем тенденция. Никаких сильных аномалий я не заметил. Цены размещаются в освноной массе до 10 миллионов. Есть аномальное значение в районе 150000, такое возможно для квартир в плачевном состоянии и далеко от цивилизации. Высота размещается в районе 2.7 метров. Я не уверен, но возможно, из-за моих замен высот появились пики в районе 2,5 и 3 метров.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Молодец, что кроме построения гистограмм дополнил еще и описанием

# %%
df.boxplot('days_exposition', 'weekday')
# Out:
# <AxesSubplot:title={'center':'days_exposition'}, xlabel='weekday'>

# %% [markdown]
# К концу недели можно заметить, что скорость продаж увеличивается.

# %%
df.boxplot('days_exposition', 'month')
# Out:
# <AxesSubplot:title={'center':'days_exposition'}, xlabel='month'>

# %% [markdown]
# В целом, зимой и осенью выставленные квартиры продаются дольше, чем квартиры выставленные летом и осенью.

# %%
df.boxplot('days_exposition', 'year')
# Out:
# <AxesSubplot:title={'center':'days_exposition'}, xlabel='year'>

# %% [markdown]
# К 2019 году скорость продаж сильно снизилась.

# %%
df['days_exposition'].hist()
# Out:
# <AxesSubplot:>

# %%
df['days_exposition'].describe()
# Out:
# count    20518.000000
# mean       180.888634
# std        219.727988
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Стандартное по долготе количество дней до продажи примерно 200 дней, медиана 219, среднее 180. Можно считать, что квартира продалась быстро, если количество дней укладывается до 45. А долго, если больше 232 дней. Выбросами считаются в большинстве своем для всех графиков количество дней более 400. Только для 2018 и 2019 года это не есть правило.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Хорошо определил границы days_exposition

# %%
right_df = df.query('days_exposition < 400')

# %%
df['last_price'].describe()
# Out:
# count    2.369900e+04
# mean     6.541549e+06
# std      1.088701e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.650000e+06
# 75%      6.800000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %%
right_df = right_df.query('last_price > 1000000')

# %%
df['total_area'].describe()
# Out:
# count    23699.000000
# mean        60.348651
# std         35.654083
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.900000
# max        900.000000
# Name: total_area, dtype: float64

# %%
right_df = right_df.query('18 < total_area < 631')

# %%
df['ceiling_height'].describe()
# Out:
# count    23699.000000
# mean         2.687851
# std          0.178325
# min          2.400000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max          3.500000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Правда, посмотрел гистограммы, которые строил, нашел странные значения. Цену ограничил от миллиона рублей снизу, поискал в интернете, минимальные цены по Санкт-Петербургу и области, ниже не найдешь. Площадь ограничил с двух сторон, т.к. студии минимум примерно 17-18 квадратов, а а максимальная площадь в Санкт-Петербурге 631 квадратный метр:) А по высоте потолков я ранее сделал ограничение по высоте.</div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера ❌:</b> "Редкие и выбивающиеся" значения есть не только в days_exposition и убрать их можно не только оттуда, обрати пожалуйста на это внимание и дополни этот раздел

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Да, теперь все как надо </div>

# %%
print(right_df['last_price'].corr(right_df['total_area']))
# Out:
# 0.6055119949526533

# %%
right_df.plot(x='total_area', y='last_price', kind='scatter')
# Out:
# <AxesSubplot:xlabel='total_area', ylabel='last_price'>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Зависимость есть, с увеличением площади растет и цена, но это не является правилом для всех квартир. Некоторые квартиры с меньшей площадью дороже квартир больших по площади.</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Верно </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера ❌:</b> Корреляция Пирсона может указать только на наличие\отсутствие линейной зависимости, а она может быть и нелинейной. Пожалуйста дополни анализ в этом разделе(диаграмма рассеяния хорошо справится с это задачей)

# %%
print(right_df['last_price'].corr(right_df['rooms']))
# Out:
# 0.3291134885285777

# %%
right_df.plot(x='rooms', y='last_price', kind='scatter')
# Out:
# <AxesSubplot:xlabel='rooms', ylabel='last_price'>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> С увеличением количества комнат в какой-то момент растет и цена, но после примерно 7 комнат цена падает, скорее всего это выбросы или какая-то аномалия. Возможно это связано с плохим состоянием квартир</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Хорошо </div>

# %%
print(right_df['last_price'].corr(right_df['cityCenters_nearest']))
# Out:
# -0.1844073347309355

# %%
right_df.plot(x='cityCenters_nearest', y='last_price', kind='scatter')
# Out:
# <AxesSubplot:xlabel='cityCenters_nearest', ylabel='last_price'>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> С увеличением расстояния от центра стоимость квартир падает в большинстве случаев, есть выбросы, но возможно, имеется элитная недвижимость подальше от центра) Я пересмотрел свои заключения, все параметры несут влияние на цену, есть исключения из правил, но так или иначе зависимости есть определенно.</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Да, все здорово дополнил </div>

# %% [markdown]
# Наибольшее влияние из трех параметров несет в себе площадь. При увелечении одного растет и другое. Количетсво комнат и расстояние до центра особого влияния не несут.

# %%
print(right_df['last_price'].corr(right_df['weekday']))
# Out:
# 0.003900930416188157

# %%
right_df.pivot_table(index='weekday', values=['price_for_metr'], aggfunc='mean').plot(title = 'price_for_metr/weekday', style='o-', grid=True, figsize=(12, 5))
# Out:
# <AxesSubplot:title={'center':'price_for_metr/weekday'}, xlabel='weekday'>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера ❌:</b> А по временным параметрам лучше построить линейный график

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Графики стали гораздо более наглядными </div>

# %%
print(right_df['last_price'].corr(right_df['month']))
# Out:
# 0.00012840757720201744

# %%
right_df.pivot_table(index='month', values=['price_for_metr'], aggfunc='mean').plot(title = 'price_for_metr/month', style='o-', grid=True, figsize=(12, 5))
# Out:
# <AxesSubplot:title={'center':'price_for_metr/month'}, xlabel='month'>

# %%
print(right_df['last_price'].corr(right_df['year']))
# Out:
# -0.031311897916500284

# %%
right_df.pivot_table(index='year', values=['price_for_metr'], aggfunc='mean').plot(title = 'price_for_metr/year', style='o-', grid=True, figsize=(12, 5))
# Out:
# <AxesSubplot:title={'center':'price_for_metr/year'}, xlabel='year'>

# %% [markdown]
# Дата размещения не несет никакого влияния на цену.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Получилось, что в выходные дни цены выше, чем в будни. По месяцам цены растут и падают волнами. По годам заметно, что с 2014 года было падение цен, однако с 2017 года цены начали расти на недвижимость </div>

# %%
display(right_df.groupby('locality_name').count().sort_values(by='last_price', ascending=False).head(10))
# Out:
#                    total_images  last_price  total_area  first_day_exposition  \
# locality_name
# Санкт-Петербург           11819       11819       11819                 11819
# посёлок Мурино              473         473         473                   473
# посёлок Шушары              368         368         368                   368
# Всеволожск                  289         289         289                   289
# Колпино                     280         280         280                   280
# посёлок Парголово           271         271         271                   271
# Пушкин                      266         266         266                   266
# деревня Кудрово             261         261         261                   261
# Гатчина                     230         230         230                   230
# Выборг                      179         179         179                   179
#
#                    rooms  ceiling_height  floors_total  living_area  floor  \
# locality_name
# ...

# %%
top_ten_df = right_df.pivot_table(index='locality_name', values='price_for_metr', aggfunc=['count','mean'])

# %%
top_ten_df.columns = ['count', 'mean']

# %%
display(top_ten_df.sort_values(by='count', ascending=False).head(10))
# Out:
#                    count           mean
# locality_name
# Санкт-Петербург    11819  111367.420894
# посёлок Мурино       473   86082.822413
# посёлок Шушары       368   78101.271587
# Всеволожск           289   69080.639749
# Колпино              280   74774.623283
# посёлок Парголово    271   89009.473490
# Пушкин               266  101594.056447
# деревня Кудрово      261   92699.569500
# Гатчина              230   68371.046242
# Выборг               179   57526.049631

# %%
new_top_ten_df = top_ten_df.sort_values(by='count', ascending=False).head(10)

# %%
display(new_top_ten_df.sort_values(by='mean', ascending=False).head(10))
# Out:
#                    count           mean
# locality_name
# Санкт-Петербург    11819  111367.420894
# Пушкин               266  101594.056447
# деревня Кудрово      261   92699.569500
# посёлок Парголово    271   89009.473490
# посёлок Мурино       473   86082.822413
# посёлок Шушары       368   78101.271587
# Колпино              280   74774.623283
# Всеволожск           289   69080.639749
# Гатчина              230   68371.046242
# Выборг               179   57526.049631

# %% [markdown]
# Самым дорогим является Санкт-Петербург. Соответственно самым дешевым Выборг.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Ты правильно ответил на вопрос задания!

# %%
right_df=df.query('locality_name == "Санкт-Петербург"')

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера ⚠️:</b> Для борьбы с warnings могу посоветовать такой прием:
#
# import warnings
#
# warnings.filterwarnings("ignore")

# %%
import warnings

warnings.filterwarnings("ignore")

right_df['cityCenters_nearest_km'] = (right_df['cityCenters_nearest']/1000).dropna().astype('int')

# %%
display(right_df['cityCenters_nearest_km'])
# Out:
# 0        16.0
# 2        13.0
# 3         6.0
# 4         8.0
# 7        11.0
#          ...
# 23689    16.0
# 23690     6.0
# 23691     4.0
# 23694     4.0
# 23697    10.0
# Name: cityCenters_nearest_km, Length: 15721, dtype: float64

# %% [markdown]
# Построим график зависимости удаленности от центра.

# %%
right_df_pivot = right_df.pivot_table(index='cityCenters_nearest_km', values=['price_for_metr'], aggfunc='mean')

# %%
print(right_df_pivot)
# Out:
#                         price_for_metr
# cityCenters_nearest_km
# 0.0                      187324.130319
# 1.0                      166603.755531
# 2.0                      146662.860056
# 3.0                      129416.344615
# 4.0                      137475.497055
# 5.0                      146979.232519
# 6.0                      152277.893519
# 7.0                      141399.731456
# 8.0                      120581.349830
# 9.0                      110012.549686
# 10.0                     111641.287182
# 11.0                     106790.883882
# 12.0                     108295.769255
# 13.0                     107209.143992
# 14.0                     104986.483351
# 15.0                     101883.116013
# 16.0                     100085.601721
# 17.0                      94095.872357
# 18.0                      94831.953162
# 19.0                      95434.377295
# 20.0                     107046.166047
# 21.0                      91492.688149
# ...

# %%
right_df_pivot.plot(title = 'price_for_metr/km', style='o-', grid=True, figsize=(12, 5))
# Out:
# <AxesSubplot:title={'center':'price_for_metr/km'}, xlabel='cityCenters_nearest_km'>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Действительно, видимо 7 км это и есть граница центра города

# %% [markdown]
# Судя по графику самый резкий спад идет от 0 до 3 км от центра, но это слишком маленький радиус, возможно это связано со старым жильем в центре города, поэтому я считаю, что центр заканчивается примерно в 6-7 км от центра, когда начинается стабильный спад цены.

# %%
right_df_nearest = right_df.query('cityCenters_nearest_km < 7').reset_index(drop=True)

# %%
print(right_df_nearest)
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 0                0    64900000      159.00           2015-07-24      3
# 1                8     6500000       97.20           2015-10-31      2
# 2                6    15500000      149.00           2017-06-26      5
# 3                7    45000000      161.00           2017-10-17      3
# 4               20    11795000      136.00           2017-09-22      6
# ...            ...         ...         ...                  ...    ...
# 3300             5     9000000      110.00           2015-12-10      4
# 3301            11     4250000       47.00           2016-05-20      1
# 3302             3     5500000       52.00           2018-07-19      2
# 3303            11     9470000       72.90           2016-10-13      2
# 3304             9     9700000      133.81           2017-03-21      3
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %%
right_df_nearest.pivot_table(index='category_floor', values=['price_for_metr'], aggfunc='mean').plot(title = 'price_for_metr/floor', style='o-', grid=True, figsize=(12, 5))
# Out:
# <AxesSubplot:title={'center':'price_for_metr/floor'}, xlabel='category_floor'>

# %%
df.pivot_table(index='category_floor', values=['price_for_metr'], aggfunc='mean').plot(title = 'price_for_metr/floor', style='o-', grid=True, figsize=(12, 5))
# Out:
# <AxesSubplot:title={'center':'price_for_metr/floor'}, xlabel='category_floor'>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Цены в среднем ниже для всего датафрейма. Но закономерность одинаковая, дешевым является первый этаж, подороже последний, а все, что входит между ними дороже всего. </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера ❌:</b> Хорошо, но тут все же стоит посмотреть на зависимость от категории этажа и сравнить с зависимостью в общей базе

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Замечательно </div>

# %% [markdown]
# В целом, цена за метр растет с увеличением этажа, но после 10 этажа начинаются колебания цены.

# %%
right_df_nearest.pivot_table(index='cityCenters_nearest_km', values=['price_for_metr'], aggfunc='mean').plot(title = 'price_for_metr/km', style='o-', grid=True, figsize=(12, 5))
# Out:
# <AxesSubplot:title={'center':'price_for_metr/km'}, xlabel='cityCenters_nearest_km'>

# %%
print(right_df_nearest['cityCenters_nearest_km'].corr(right_df_nearest['price_for_metr']))
# Out:
# -0.03068993962835232

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Слабая закономерность есть, судя по корреляции, с увеличением отдаления от центра, уменьшается стоимость.  </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Правильно </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера ⚠️:</b> Тут верно, но стоит дополнить анализом корреляции Пирсона, чтобы тчнее понять наличие/отсутствие линейной зависимости

# %% [markdown]
# Цена с отдалением от центра не поменяла своего поведения после исследования на предыдущем этапе.

# %%
right_df_nearest.pivot_table(index='weekday', values=['price_for_metr'], aggfunc='mean').plot(title = 'price_for_metr/day', style='o-', grid=True, figsize=(12, 5))
# Out:
# <AxesSubplot:title={'center':'price_for_metr/day'}, xlabel='weekday'>

# %%
right_df_nearest.pivot_table(index='month', values=['price_for_metr'], aggfunc='mean').plot(title = 'price_for_metr/month', style='o-', grid=True, figsize=(12, 5))
# Out:
# <AxesSubplot:title={'center':'price_for_metr/month'}, xlabel='month'>

# %%
right_df_nearest.pivot_table(index='year', values=['price_for_metr'], aggfunc='mean').plot(title = 'price_for_metr/year', style='o-', grid=True, figsize=(12, 5))
# Out:
# <AxesSubplot:title={'center':'price_for_metr/year'}, xlabel='year'>

# %% [markdown]
# <div class="alert alert-info"> <b> Получилось, что в выходные дни цены выше, чем в будни. По месяцам цены растут и падают волнами, ощущение, что в некоторые месяцы спрос просто ниже и рынок не такой активный, например, после новогодних праздников или после начала учебного года в сентябре у всех другие заботы, майские праздники:) По годам заметно, что с 2014 года было падение цен, однако с 2018 года цены начали расти на недвижимость. Тенденции сохранились, как и во всем датайфрейме, а цены выше на квадратный метр. </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Совершенно верно</div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера ❌:</b> А здесь необходимо отдельно посмотреть на зависимость от дня, месяца и года

# %% [markdown]
# Конкретной зависимости от дня не наблюдаю.

# %%
right_df_nearest['total_area'].hist(bins=100)

# %% [markdown]
# Пик по общей площади квартир сместился ближе к 100 в отличие от всего дата фрейма.

# %%
right_df_nearest['last_price'].hist(bins=100, range=(0, 30000000))

# %% [markdown]
# Цена сместилась в большую сторону в отличие от всего датафрейма

# %%
right_df_nearest['rooms'].hist(bins=15)

# %% [markdown]
# Количество комнат в среднем 2-3

# %%
right_df_nearest['ceiling_height'].hist()

# %% [markdown]
# Высота потолков примерно такая же

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> А вот гистограммы по основным параметрам построил здорово!

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Самым дорогим городом по квартирам и с самым большим количеством предложений является Санкт-Петербург. С отдалением от центра уменьшается и цена на квадратный метр, поэтому удаление от центра можно занести как определяющий фактр в строимость квартир. Также по сравнению со всем датафреймом в Санкт-Петербурге цены и общие площади больше всего датафрейма. Также с ростом этажа можно наблюдать увеличение цены, но не на всех всех этажах такая тенденция соблюдается. Высоты потолков примерно одинаково распределяются как в основном датафрейме так и в урезанном по центру датафрейму.

# %% [markdown]
# <div class="alert alert-info"> <b> Можно добавить, что выявились закономерности от дня, месяца и года на цены. Например, в выходные цены выше, по месяцам сильно влияние активности рынка, в целом, таже было падение цен с 2014 года и рост после 2017-2018. Тенденции для лучшей десятки и для всего датафрема не изменились </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Хорошее дополнение, все уместно </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Супер, подробные и хорошие выводы

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Дмитрий, проект отличный! У тебя очень сильные аналитические навыки и владение инструментами для проведения исследования. Но всё же в проекте есть несколько замечаний и я попрошу тебя исправить их, чтобы он стал еще лучше! </div>

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: «Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?»
# - [x]  выполнено задание: «Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили».
# - [x]  выполнено задание: «Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года».
# - [x]  выполнено задание: «Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце `locality_name`».
# - [x]  выполнено задание: «Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (`locality_name`). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона».
# - [x]  выполнено задание: «Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?»
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод
