# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Итак, мои комментарии на этот раз будут зелёными, в заголовке иметь версию V2 (как у этого!) и в них я буду стараться ответить на твои вопросы, если таковые увижу (мелкие/"проходные" изменения/исправления в тексте проекта, каждое из них, не буду с твоего позволения комментировать - только те моменты, где я что-то более-менее не банальное могу сказать. Хорошо? Будем считать, что, если комментария на твое исправление нет - значит я согласен с тобой в этом пункте).
#
# ………………
#
# Дмитрий - я вижу, что все красные комментарии учтены, код исправлен, выводы актуализированы. Соответственно никаких вопросов/моментов/комментариев, мешающих принять твой проект у меня более нет.
#
# ПРОЕКТ ПРИНЯТ!
#
# Я же в свою очередь, ниже попытался ответить на все твои вопросы (если видел, что они есть).
#
# Желаю тебе успехов в учёбе, желаю, чтобы проекты сдавались или сразу, или после первой итерации! Удачи!
#
# p.s. я тебе на твой адрес эл/почты сейчас вышлю некоторые материалы из своей электронной библиотеки - надеюсь они будут тебе полезными в учёбе.</div>

# %% [markdown]
# Привет Дмитрий!
#
# Меня зовут Александр Непомнящий и я буду проверять твой проект. Предлагаю общаться на «ты» :))) Но, если это не удобно - мы вполне можем перейти на вы".
#
# Вкратце обо мне: я работаю в сфере информационных технологий, аналитика (анализ) данных - это и мой рабочий функционал и личная, интересная мне область для саморазвития. Используемый стек: python, pandas, графические библиотеки matplotlib/seaborn/plotly. Сфера применения: маркетинговая аналитика в медицинской клинике. Если вдруг есть вопрос – что делает аналитик в коммерческой медицине – то вот короткий ответ. Самый главный вопрос, на который мы хотим получить ответ (и который в дальнейшем приведёт к перераспределению рекламного бюджета, плюс напрямую повлияет на разработку и предложению рынку новых лечебных программ) - это КТО ОН, НАШ КЛИЕНТ? Фактически это задача (на нашем внутреннем языке формулируется как построение и анализ «ПОРТРЕТА КЛИЕНТА»). Визуализируем и пытаемся придать смысл половозрастным данным наших клиентов, кто из какого региона и в какие времена года к нам приезжает. Учитываем количество приездов. Учитываем на какую программу этот конкретный клиент приехал в первый раз и как в дальнейшем меняются его предпочтения. Пытаемся построить модель оттока и спрогнозировать, когда клиент уйдёт в отток. Смотрим цифры (суммы трат клиентов на отдельных группах медицинских программ). Анализируем медицинские услуги, которые входят в путёвку, а также что, в каких количествах и на какую сумму клиент покупает дополнительно. Очень вкратце как-то так.
#
# Теперь к сути: основная цель моей проверки - пройти по шагам, по логике твоего решения и обсудить те моменты, которые можно изменить, улучшить, довести до идеала. Такой формат работы двух программистов (аналитиков) ты или уже встречал(а), или встретишь на своей новой работе. Кто-то такой процесс называет "код-ревью", ну а как по мне, так это обмен опытом двух коллег, когда каждый из нас становиться лучше в процессе дискуссии.
#
# Свои мысли, советы, комментарии и вопросы я буду оставлять в текстовых ячейках (markdown) ПОД твоим кодом.
# Для твоего удобства все эти заметки будут "цветными", как на примерах ниже:
#
# "Зелеными" комментариями я буду отмечать твой элегантный ("красивый") код и/или удачные решения, на которые ты можешь смело опираться в будущих проектах.
# <div class="alert alert-success">
# <b>Отлично! 👍</b>
#
# Отличная находка, элегантный код ...</div>
#
# "Жёлтые" комментарии - это мои размышления, предложения, что-то, что в следующий раз можно сделать по-другому. "Жёлтые" комментарии не требуют твоих правок в проекте и их наличие НИКАК не повлияет на результат моей проверки. Но я искренне верю, что наш двусторонний диалог под "желтым" комментарием - это то, от чего твой проект только выиграет.
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Здесь я бы предложил использовать .... Мои аргументы в пользу этого ...</div>
#
# "Красные" комментарий будут появляться, когда что-то пойдёт не так: например, код будет выдавать ошибку. Или, когда в проекте не будет ответов на основные вопросы, ради которых весь анализ и выполнялся. "Красные" комментарии необходимо будет исправить, прежде чем я смогу принять проект.
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# В этой ячейке код работает не так как задумано ...</div>
#
# Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии. Это поможет мне оперативно выполнить повторную проверку твоего проекта.
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом, лучше всего в новой ячейке, сразу под моим комментарием. Если для своих комментариев ты будешь использовать какой-то заметный цвет, то мне будет легче отследить твои изменения, например так:
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Текст твоего комментария ...</font>
# </div>
#
# Ну и наконец информируй меня в том случае, если по твоему проекту подходит дедлайн! В таком случае я приложу усилия, чтобы ты сдал(а) его вовремя; буду оперативно, в приоритете проверять итерации ревью, а также отвечать на твои вопросы, если этого будет требовать ситуация.
#
# **Распространенные типичные недочёты в проектах студентов:**
#
# <div class="alert alert-danger" ❌>
# Неработоспособный код. Проверь проект на работоспособность перед отправкой на проверку. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании.</div>
#
# <div class="alert alert-danger" ❌>
# Проект не структурирован. В проекте должна быть структура, т.е. названия разделов и подразделов должны быть записаны в ячейках Markdown.</div>
#
# <div class="alert alert-warning" 👉 >
# Отсутствие описания, целей проекта, его задач, выводов. В описании должны быть озвучены поставленные задачи, содержание датасета, промежуточные и финальные выводы. Как правило, заказчик читает только финальный вывод, поэтому важно добавить информацию о проведенном исследовании, применить форматирование текста, в общем, сделать красиво, чтобы было понятно, что проведено настоящее исследование и выводу можно верить.</div>
#
# <div class="alert alert-warning" 👉 >
# "Длинный код". Код и и комментарии, которые прячутся за правым концом ячейки нужно переносить на новую строку. Твои будущие коллеги не оценят необходимость постоянного скроллинга. Согласно PEP8: https://www.python.org/dev/peps/pep-0008/ длина строки не должна превышать 79 символов.</div>
#
# <div class="alert alert-warning" 👉 >
# Твои коллеги ценят и твое и своё время, поэтому "подсвечивай" свои комментарии в ячейках Markdown. Подробнее про синтаксис Markdown, с примерами, можно почитать здесь: https://paulradzkov.com/2014/markdown_cheatsheet/?</div>

# %% [markdown]
# В данной работе целью будет являться следующее: нужно определить какие факторы влияют на успешность игры, чтобы выбрать потенциально успешную игру для следующего года и спланировать рекламные кампании.
# Задачи:
# 1. Ознакомиться с данными
# 2. Выполнить предобратку данных
# 3. Выполнить исследовательский анализ данных
# 4. Определить для каждого региона портрет пользователя, какие игры популярны, какие самые продавыемые и т.д.
# 5. Проверить гипотезы
# 6. Сделать финальный вывод по работе

# %% [markdown]
# 1. Изучение данных

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats as st

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Все импорты принято собирать в одну, самую первую ячейку кода проекта. Дробить не надо.
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'> Поправил </font>
# </div>

# %%
df = pd.read_csv('/datasets/games.csv')

# %%
df.head(5)
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Выводить много строк из датафрейма можно, но как правило я так не делаю (пространство на мониторе конЕчно, особенно когда в нескольких ячейках необходимо последовательно посмотреть, что в датафрейме изменилось). Достаточно "типового" .head() с 5 строками - как подтверждение того, что данные в датафрейм загружены верно. Если же в твоём случае считать, что 30 строк  - это как массив из которого будут видны **все** проблемы с данными (пропуски, аномальные значения), то поверь, для датафрейма с 16+ тысячами записей 30 строк это "капля в море". Может случиться так, что проблемы видны и не будут. Для анализа же мы будем использовать другие инструменты: .info(), .describe() и т.д.</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Поправил</font>
# </div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         Other_sales  Critic_Score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %% [markdown]
# Первые выводы:
# 1. Можно заметить что имена столбцов написаны в разных регистрах
# 2. Типы данных некоторых столбцов нужно поменять в зависимости от ситцации. Для года логично использовать целочисленные тип, например.
# 3. Есть пропуски
# 4. Стобцов 11, строк 16715

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Спасибо за вывод по предварительному анализу загруженных данных. Зачастую коллеги ограничиваются исключительно кодом, без слов. Ввиду чего непонятно к каким выводам они пришли и что собираются делать дальше.</div>

# %% [markdown]
# 2. Предобработка данных

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# **Прежде чем производить какие-либо модификации данных (удалять пропуски / заполнять пропуски «заглушкой / оставлять пропуски «как есть») хотелось бы порассуждать на тему природы пропусков в наших данных**.
#
# Одна из задач этого проекта (согласно брифа):
#
# 1. Объясните, почему заполнили пропуски определённым образом или почему не стали это делать,
#
# 2. Опишите причины, которые могли привести к пропускам
#
# 3. Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите, как его обработать.
#
# 4. Также, скажи пожалуйста, какова на твой взгляд причина того, что в столбце с оценками экспертов, с оценками пользователей и с рейтингами так много пропусков? Как ты считаешь, может ли быть какая-то связь с тем, что в столбце с рейтингами >40% пропусков и тем, что эти оценки (рейтинги) выставляет **именно Американское рейтинговое агентство**?</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>
#
#         1. По столбцам с маленьким количеством пропусков было принято решение, что данные будут удалены, так как таких строк довольно мало, для столбца с годами пропусков примерно 1,5%. Пропуски в оценках: оценки игр комплексны, состоят из многих факторов, например, графика или геймплей. Я считаю, что мы не можем просто взять и запомлнить пропуски медианным или средним значением, это не как заполнить высоту потолка в квартире. Заменил в конце работы пропуски в рейтинге, так как они были нужны для оценки кол-ва и понимания, как влияет рейтинг на продажи.
#
#         2. Причинами пропусков в столбцах с именем, жанром может быть техническая, вроде "битых данных". По годам отсутствие данных может нести как технический характер, так и, например, это может означать, что игра еще не вышла. Пропуски в оценках могут носить разный характер, но скорее всего оценка либо не проставлена, либо в данной базе данных нет других оценок, либо по "политическим" причинам нет оценок. В по пропускам в оценках нужно пообщаться с экспертами в области, но в данный момент такой возможности нет.
#
#         3. TBD - аббревиатура от английского To Be Determined (будет определено) или To Be Decided (будет решено). Используется, если какая-то информация еще не определена или решение по вопросу не принято. Акроним служит для отметки неясностей или пропусков, которые надо заполнить, в информации требований. В моей работе так получилось, что я заменил значения TBD при переводе даных столбца в другой формат, но можно использовать заглушку, например, заменить на -1, после чего произвести замену типа данных, но нужно будет не забыть про нее при дальнейшем анализе. Я решил, что пропуски, которые получились в силу замены типа данных, я уберу при анализе. Тоже самое я бы сделал с заглушкой.
#
#         4. Как я понял, что касается рейтингов, все зависит от того, в какой стране игра будет продаваться. Я так понимаю, что причиной может являться нежелание разработчика игры платить в Американское рейтиноговое агенство (ESRB), также проблемой может быть, что рецензенты могут не сойтись в решении, какую оценку поставить, также вопрос откуда взяты оценки для данных игр. Возможно, оценки, как и рейтинг взяты для одной страны. </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Да, принял, всё так.
# </div>

# %%
df.columns = df.columns.str.lower()

# %%
df.isna().sum() # проверил данные на пропуски
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %%
df['year_of_release'] = pd.to_numeric(df['year_of_release'], downcast='integer', errors = 'coerce')

# %%
df['year_of_release'].unique()
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2016., 2003., 1986., 2000.,   nan, 1995., 1991., 1981., 1987.,
#        1980., 1983.])

# %% [markdown]
# Оставил тип данных в годах, так как выдавало ошибку при замене в целочисленный тип.

# %%
df['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %%
df['user_score'] = pd.to_numeric(df['user_score'], downcast='float', errors = 'coerce')

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# В серьёзном и важном продакшн коде я бы не стал сразу использовать errors='coerce', а вначале бы явно "прогнал код" используя errors='raise' (ну или вообще удалив errors=..., потому что 'raise' 'это значение по умолчанию). Почему? Потому что errors='coerce' все "неправильные" значения сделает NaN и никаких сообщений об этом не будет, т.е. потенциально данные в серии 'user_score' мы можем испортить.</div>

# %% [markdown]
# Заменил тип данных на float, т.к. оценки должны быть в целочисленном либо десятичном формате

# %%
df['user_score'].unique()
# Out:
# array([8. , nan, 8.3, 8.5, 6.6, 8.4, 8.6, 7.7, 6.3, 7.4, 8.2, 9. , 7.9,
#        8.1, 8.7, 7.1, 3.4, 5.3, 4.8, 3.2, 8.9, 6.4, 7.8, 7.5, 2.6, 7.2,
#        9.2, 7. , 7.3, 4.3, 7.6, 5.7, 5. , 9.1, 6.5, 8.8, 6.9, 9.4, 6.8,
#        6.1, 6.7, 5.4, 4. , 4.9, 4.5, 9.3, 6.2, 4.2, 6. , 3.7, 4.1, 5.8,
#        5.6, 5.5, 4.4, 4.6, 5.9, 3.9, 3.1, 2.9, 5.2, 3.3, 4.7, 5.1, 3.5,
#        2.5, 1.9, 3. , 2.7, 2.2, 2. , 9.5, 2.1, 3.6, 2.8, 1.8, 3.8, 0. ,
#        1.6, 9.6, 2.4, 1.7, 1.1, 0.3, 1.5, 0.7, 1.2, 2.3, 0.5, 1.3, 0.2,
#        0.6, 1.4, 0.9, 1. , 9.7], dtype=float32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float32
#  10  rating           9949 non-null   object
# dtypes: float32(1), float64(6), object(4)
# memory usage: 1.3+ MB

# %% [markdown]
# Заменил данные только в двух столбцах, в остальных, на мой взгляд, типы данных соответствуют данным в столбцах.

# %% [markdown]
# Пропуски смотрел выше по коду. Можно удалить пропуски в столбцах, где все два пропуска. В местах, где много пропусков нужно будет смотреть, от чего зависят оценки.

# %%
df = df.dropna(subset=['name', 'year_of_release', 'genre'])

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Перед удалением, операцией по сути деструктивной, я бы рекомендовал посмотреть на записи с пропусками в соответствующих колонках, по отдельности. 2 строки с пропусками в 'name' (из 16+ тысяч) - это капля в море, можно удалить наверное и сразу ... 269 записей с пропусками в годе выпуска тоже вроде немного, но ты учитывай тот факт, что все задачи в это проекте так или иначе связаны как раз с годом выпуска ... "В жизни" лишний взгляд на данные лишним не бывает.</div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# И ещё небольшой, но жизненный совет: **перед** и **сразу после** удаления строк (и для столбцов тоже будет верно) примени метод .shape к датафрейму. В этом случае наглядно будет видно сколько строк/столбцов было удалено. В некоторых ситуациях может быть ошибка в коде из-за которой удаляется больше чем ожидалось. Но этот способ поможет тебе такую проблему сразу вычислить.</div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# (Немного рассуждений): да, всего 2 записи (из 16 тысяч) с пропусками в жанрах и названиях (плюс в этих же записях нет ни оценок пользователей, ни оценок критиков, ни рейтингов) и 269 записей (менее 2% из 16+ тысяч) с пропусками в годах выпуска. Надо удалять даже не раздумывая …
#
# Хотя конечно, единого сценария нет на самом деле. С одной стороны - да, говорят, что "данных много не бывает", удалять записи из-за пропусков, когда датасет измеряется сотнями-тысячами записей ой как не хочется.
#
# С другой стороны, если запись не спасти, если в ней несколько полей не заполнено или не заполнены ключевые поля, и ты чувствуешь, что заполнение их медианами/средними приведёт к смещению статистик - надо удалять. Да, можно поставить "заглушку", но тогда надо отдавать отчёт, что во всем последующем коде про эту "заглушку" помнить придётся. Т.е. перед построением всех графиков, гистограмм заглушку надо будет удалить. Перед расчетом корреляций - заглушку надо будет удалить. Перед проверкой гипотез заглушку надо будет удалить.
#
# Я бы так определил способ решения такой задачи: если записи с пропусками в ключевых для моего анализа полях составляют 1-3-5-до 10% строк, то я бы их из оригинального датафрейма вырезал (но сохранил бы в некий df, к которому при необходимости мог бы обратиться).
#
# А вообще, в таких случаях, когда нужно решить - заполнять пропуски или удалять строки с ними из df - всегда ищи эксперта в предметной области и советуйся с ним. Как правило это человек из бизнеса, который значит суть бизнес-процесса и вот именно он даст тебе точный и аргументированный совет - что в данной, конкретной задаче делать с "битыми" полями в строках датафрейма.</div>

# %%
#df['name'].value_counts().head(50)

# %%
df.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8461
# user_score         8981
# rating             6676
# dtype: int64

# %%
df['user_score'].unique()
# Out:
# array([8. , nan, 8.3, 8.5, 6.6, 8.4, 8.6, 7.7, 6.3, 7.4, 8.2, 9. , 7.9,
#        8.1, 8.7, 7.1, 3.4, 5.3, 4.8, 3.2, 8.9, 6.4, 7.8, 7.5, 2.6, 7.2,
#        9.2, 7. , 7.3, 4.3, 7.6, 5.7, 5. , 9.1, 6.5, 8.8, 6.9, 9.4, 6.8,
#        6.1, 6.7, 5.4, 4. , 4.9, 4.5, 9.3, 6.2, 4.2, 6. , 3.7, 4.1, 5.8,
#        5.6, 5.5, 4.4, 4.6, 5.9, 3.9, 3.1, 2.9, 5.2, 3.3, 4.7, 5.1, 3.5,
#        2.5, 1.9, 3. , 2.7, 2.2, 2. , 9.5, 2.1, 3.6, 2.8, 1.8, 3.8, 0. ,
#        1.6, 9.6, 2.4, 1.7, 1.1, 0.3, 1.5, 0.7, 1.2, 2.3, 0.5, 1.3, 0.2,
#        0.6, 1.4, 0.9, 1. , 9.7], dtype=float32)

# %%
df['critic_score'].unique()
# Out:
# array([76., nan, 82., 80., 89., 58., 87., 91., 61., 97., 95., 77., 88.,
#        83., 94., 93., 85., 86., 98., 96., 90., 84., 73., 74., 78., 92.,
#        71., 72., 68., 62., 49., 67., 81., 66., 56., 79., 70., 59., 64.,
#        75., 60., 63., 69., 50., 25., 42., 44., 55., 48., 57., 29., 47.,
#        65., 54., 20., 53., 37., 38., 33., 52., 30., 32., 43., 45., 51.,
#        40., 46., 39., 34., 41., 36., 31., 27., 35., 26., 19., 28., 23.,
#        24., 21., 17., 13.])

# %%
df['rating'].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %% [markdown]
# Аббревиатура TBD может расшивровываться как "to be determined", что не является прямым пропуском. Может и есть какие-то значения у данных, но пока нет точной оценки. Получилось так, что с заменой типа данных в столбце user_score я заменил значения TBD на nan, но при попытке заменить пропуски, заменяются не все. Заменять пропуски в оценках считаю некорректным, т.к. оценки состоят из множества факторов.

# %%
df['all_sales'] = df['na_sales']+df['eu_sales']+df['jp_sales']+df['other_sales'] # сумма всех продаж

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Ещё такой вариант суммирования есть (просто как альтернатива … **псевдокод**): **data[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis='columns')** и "присвоить" этот результат новому столбцу в **data**.</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# То, что ты в 'critic_score' и 'user_score' (после обращения tbd в NaN) оставляешь NaN'ы без обработки - значительно упростит тебе жизнь дальше. В этом проекте - это верное решение.</div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Один из ключевых моментов этого проекта: ты пропуски в 'rating' оставляешь как NaN, без заполнения «заглушкой». Это ОК здесь. Но дальше, когда мы будем строить график для игр в соответствии с их рейтингами - надо будет вспомнить этот момент ... Если не вспомнишь и не обработаешь эти "пропуски", то из анализа игры без рейтинга исчезнут. Ну и соответственно мы сделаем неправильные выводы.
#
# Отметь этот момент - возможно нам придется вернуться сюда.</div>

# %% [markdown]
# Поиск дубликатов

# %%
df['name'] = df['name'].str.lower()

# %%
df['platform'] = df['platform'].str.lower()

# %%
df['name'].value_counts()
# Out:
# need for speed: most wanted       12
# ratatouille                        9
# lego marvel super heroes           9
# fifa 14                            9
# lego batman 3: beyond gotham       8
#                                   ..
# sd gundam g generation spirits     1
# smuggler's run: warzones           1
# rogue galaxy                       1
# combat mission: shock force        1
# wipeout xl                         1
# Name: name, Length: 11426, dtype: int64

# %%
df['platform'].value_counts()
# Out:
# ps2     2127
# ds      2121
# ps3     1306
# wii     1286
# x360    1232
# psp     1193
# ps      1190
# pc       957
# gba      811
# xb       803
# gc       542
# 3ds      512
# psv      429
# ps4      392
# n64      316
# xone     247
# snes     239
# sat      173
# wiiu     147
# 2600     116
# nes       98
# gb        97
# dc        52
# gen       27
# ng        12
# ws         6
# scd        6
# 3do        3
# tg16       2
# pcfx       1
# gg         1
# Name: platform, dtype: int64

# %%
df['name'].duplicated().sum()
# Out:
# 5018

# %%
df['platform'].duplicated().sum()
# Out:
# 16413

# %%
df.duplicated(subset=['name', 'platform']).sum()
# Out:
# 3

# %%
df = df.drop_duplicates(subset=['name', 'platform'])

# %%
df.duplicated(subset=['name', 'platform']).sum()
# Out:
# 0

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'> Обнаружил довольно большое количество дубликатов в стройках с именем и платформой, но они логичны, т.к. платформы могут повторяться и меняться для каждой игры, как пример ГТА может быть и на ПК и на PS4. Нашел дубликаты для пары игра-платформа, три штуки, это не много. Принял решение удалить. </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Да, вижу код.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Любая предобработка данных предполагает поиск и анализ дубликатов. В твоём разделе EDA (== Exploratory Data Analysis) подобной важной составляющей нет.
#
# Попробуй найти 1. явные и 2. неявные дубликаты (для их поиска нужно использовать параметр **subset**). Конкретно в нашем рабочем проекте пробуй найти дубликаты для пары "Имя - Игровая консоль".
#
# После поиска и обнаружения - опиши как их планируешь и планируешь ли обрабатывать?</div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Меня смущает отсутствие полноценного вывода в этом разделе, например, с описанием того что здесь делали? Зачем делали? Какие результаты получили? Что будем делать с этими результатами?
#
# Нужно больше слов, больше выводов, больше размышлений. Аналитика данных - это скорее "про выводы по данным", нежели чем про "про написание кода". Нет, программирование конечно в аналитике тоже занимает большой % времени, но построение выводов, уточнение формулировок и подготовка презентаций (например в PowerPoint) тоже значительную часть анализа занимает.</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Выводы в начале этой части</font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Данные загружены, отлично.
#
# Хорошо, что применяешь метод .head()/.sample() таким образом в память не будет загружен весь датасет, объем которого может быть огромным.
#
# Методы .info, .describe, .value_counts(), .unique() как правило часто встречаются и обязательны к применению в задачах по исследованию данных, ведь с их помощью можно получить первые инсайты.
#
# Итак, мы провели предварительный анализ данных, проверили данные на наличие пропусков и затем обработали их (аргументированно заполнили / удалили / оставили как есть). Теперь можно приступать собственно к анализу данных и ответам на вопросы проекта.</div>

# %% [markdown]
# 3. Ислледовательский анализ данных

# %%
df_pivot = df.pivot_table(index='year_of_release', values= ['all_sales'], aggfunc = 'sum')

# %%
df_pivot
# Out:
#                  all_sales
# year_of_release
# 1980.0               11.38
# 1981.0               35.68
# 1982.0               28.88
# 1983.0               16.80
# 1984.0               50.35
# 1985.0               53.95
# 1986.0               37.08
# 1987.0               21.70
# 1988.0               47.21
# 1989.0               73.45
# 1990.0               49.37
# 1991.0               32.23
# 1992.0               76.16
# 1993.0               45.99
# 1994.0               79.23
# 1995.0               88.12
# 1996.0              199.15
# 1997.0              201.07
# 1998.0              256.31
# 1999.0              251.11
# 2000.0              201.66
# 2001.0              331.46
# 2002.0              394.97
# 2003.0              357.54
# 2004.0              418.68
# 2005.0              456.57
# 2006.0              517.71
# 2007.0              604.75
# 2008.0              671.50
# 2009.0              658.82
# 2010.0              590.13
# 2011.0              507.58
# ...

# %%
df_pivot.plot(kind='bar', figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# До 96 года было довольно мало продаж игр, после чего их кол-во начинает расти и пик приходится на 2009-2010 года. к 2016 году уровень продаж опустился ниже уровня 97 года. Возможно, можно отсечь годы до 1996, так как продаж там мало и выхода игр тоже.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Этот график, как и все прочие ниже, выиграли бы если бы были подписаны сами (plt.title), а также оси X и Y, а также указаны единицы измерения по осям. **figsize=[20, 10]** также попробуй использовать.
#
# p.s. было бы здорово получить объяснение поведения данного графика. Пытаться понять полученный результат - важная часть работы аналитика.</div>

# %%
df_top_5 = df.pivot_table(index='platform', values= ['all_sales'], aggfunc = 'sum').sort_values(by='all_sales', ascending=False)

# %%
df_top_5
# Out:
#           all_sales
# platform
# ps2         1233.56
# x360         959.99
# ps3          931.33
# wii          891.18
# ds           802.78
# ps           727.58
# ps4          314.14
# gba          312.88
# psp          289.53
# 3ds          257.81
# pc           255.68
# gb           254.43
# xb           251.57
# nes          251.05
# n64          218.01
# snes         200.04
# gc           196.73
# xone         159.32
# 2600          86.48
# wiiu          82.19
# psv           53.81
# sat           33.59
# gen           28.35
# dc            15.95
# scd            1.86
# ng             1.44
# ws             1.42
# tg16           0.16
# 3do            0.10
# gg             0.04
# pcfx           0.03

# %% [markdown]
# Определены основные 5 платформ, для них сделаем срез и построим графики.

# %%
main_platform = ['ps2', 'x360', 'ps3', 'wii', 'ds']

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Здесь конечно, по сути, надо бы список с топ-5 платформами автоматизировано формировать. Ты только представь, что тебе нужно не 5, а скажем 150 значений указать, или в коде, в разных местах иметь разный топ-Х. Сделаешь?
#
# Ниже пример как (**псевдокод!**):
#
# tmp = data.pivot_table(index='platform', values='total_sales', aggfunc= 'sum').sort_values('total_sales', ascending=False)
#
# tmp.index[:5].tolist()</div>

# %%
df.query('platform in @main_platform').pivot_table(index='year_of_release', columns='platform', values=['all_sales']).plot(kind='bar', figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Код очень длинный (а PEP8 определяет длину строки в 79 символов) - попробуй длинные - переносить, а между строками использовать пустые строки. Ну и желательно код комментировать, хотя бы коротко (что делаешь и каков будет результат - так твоим коллегам будет проще за твоей мыслью следить).
#
# ---
# Давай обсудим стиль кодирования (программирования)? Смотри что сейчас происходит в этой ячейке (**возможно не всё применимо к твоему коду здесь, но я попытался вспомнить все часто встречающиеся недочёты**), что "режет" глаз и что можно сделать по-другому, чуть лучше:
#
# 1. Комментарии к строке кода: они должны располагаться выше соответствующей строки кода (выше строки к которой относятся) и должны быть от этой строки отделены пустой строкой. Если же они расположены справа, то для того чтобы увидеть, что там написано приходится пользоваться скроллиногом. Надо добиться того, чтобы ячейку не приходилось прокручивать, т.к. это не добавляет удобства ни при отладке кода, ни для понимания что в этой ячейке "происходит". Как альтернатива – комментарий может размещаться выше, в Markdown-ячейке.
#
#
# 2. Бывает, что встречаются очень длинные строки кода, которые также уходят за правый край ячейки. Такие строки должны разбиваться разделителем (вот таким: \\). Это best practice, требование PEP8, а именно: PEP8 определяет длину строки в 79 символов.
#
#
# 3. **В идеале**: одна ячейка - одна строка кода. Почему так? Да как минимум из соображения понятности: будучи выполненной, под этой ячейкой должен отображаться результат трансформации данных. Ты или твой коллега должны видеть, как поменялись данные после выполнения ячейки с кодом. Следующая ячейка - ещё строка кода и соответствующим output'ом. Будешь делать так - коллеги будут тебе благодарны за то, что легко будут следовать за твоей мыслью. И отладку это упрощает.
#
#     Ну и как противоположность - можно в одну ячейку "положить" результат 3-х последовательных groupby + ещё чего-нибудь. Разобраться с ходу "что происходит" будет очень трудно, придётся всё равно код разносить по ячейкам и смотреть последовательно что происходит. Но ведь логично это делать удобным способом сразу, ведь так?
#
#
# 4. Неиспользуемые, закомментированные строки выше вынеси в другую ячейку, отдельную, выше. Можешь для удобства своего прокомментировать (на память). И оставь там это код, так, чтобы он не смешивался с рабочим кодом.
# </div>

# %% [markdown]
# Продажи по годам распределяются по разному, так как каждый год могут появляться и исчезать разные платформы. С 2006 по 2011 год было максимальное количество платформ, до 2006 года они появлялись, после 2011 года стали исчезать.

# %%
years=df.pivot_table(index='platform', values='year_of_release', aggfunc=('max', 'min'))

# %%
years['difference'] = years['max'] - years['min']

# %%
years['difference'].mean()
# Out:
# 7.612903225806452

# %% [markdown]
# Примерно 7 с половиной лет срок жизни платформы.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Подтверждаю 7-9-11 лет, как корректный интервал, описывающий средний срок жизни игровой платформы.</div>

# %%
df_right_years = df.query('year_of_release >= 2014')

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Очень хорошо, что результат запроса/’среза’ ты присваиваешь новому датафрейму. Таким образом оригинальный датафрейм ты оставляешь нетронутым, не перезаписываешь (вдруг нам опять понадобятся данные из него чуть ниже). Это верное решение. Best practice. Молодец!</div>

# %% [markdown]
# Выбрал период начиная с 2010 года на основании того, что основная масса игр начала расти после 1996, а первая из топ 5 платформ образовалась в 2000 году, но к 2010 году и платформы и выпуск игр начал уменьшаться, значит стоит сконецентрировать внимание на этом тренде. Для того, чтобы не учитывать ненужные данные будет использоваться новый датафрейм. Период с 2010 года будет более актуален для анализа.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Нет, здесь ты берешь для анализа слишком большой интервал.
#
# Для стремительно развивающейся игровой индустрии период > 3-4 лет — очень много. Внутри выбранного тобой периода произошли резкие изменения, например, произошла замена одного поколения консолей следующим (PS -> PS2 -> PS3 -> PS4). Некоторые платформы совсем исчезли (например, платформа DS не имеет новых релизов игр с 2013 года, PS2 с 2011 года, PSP с 2015 года). Как думаешь - помогут нам эти платформы построить прогноз на 2017 год или всё же лучше уменьшить интервал для анализа?
#
# Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды. В нашем случае думаю, что 3 года: 2014, 2015 и неполный 2016 - ОК.
#
# Когда изменишь "горизонт" анализа и перезапустишь код в этой "тетрадке" - посмотри, как поменяется этот и все последующие выводы.</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Заменил горизонт на три года</font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Да, теперь актуальный период определен верно.
# </div>

# %%
df_pivot_sales = df_right_years.pivot_table(index='year_of_release', columns='platform', values='all_sales')

# %%
df_pivot_sales.plot(style='-o', grid=True, figsize=(20,20) )
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %% [markdown]
# Почти все платформы падают по продажам к 2016 году, некоторые даже перестали существовать (PSP, PS2). Лидирует по продажам PS4, но продажи сильно падают от года к году. Единственная платформа, которая увеличила свои продажи к 2016 году это X360.

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Да, я ошибся с горизонтом, на данном графике видно, что растет 3 DS. Остальные платформы я указал правильно</font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# +
# </div>

# %%
main_platform_2 = ['ps4', 'xone', 'wiiu', 'wii', '3ds']

# %%
df_right_years_platform = df_right_years.query('platform in @main_platform_2')

# %%
df_right_years_platform
# Out:
#                                                     name platform  \
# 31                             call of duty: black ops 3      ps4
# 42                                    grand theft auto v      ps4
# 47             pokemon omega ruby/pokemon alpha sapphire      3ds
# 77                                               fifa 16      ps4
# 87                          star wars battlefront (2015)      ps4
# ...                                                  ...      ...
# 16652                                   fast racing neo      wiiu
# 16660                                   prison architect     xone
# 16668  fujiko f. fujio characters: great assembly! sl...      3ds
# 16672      metal gear solid v: the definitive experience     xone
# 16677                   aikatsu stars! my special appeal      3ds
#
#        year_of_release         genre  na_sales  eu_sales  jp_sales  \
# 31              2015.0       Shooter      6.03      5.86      0.36
# ...

# %%
df_right_years_platform.boxplot(column='all_sales', by='platform')
plt.ylim(0, 0.85)
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Это хорошо! Часто студенты рисуют только график с боксплотами, на которых видны выбросы, а сами "ящики" сплющиваются так, что квартилей не разобрать.
#
# p.s. попробуй использовать ylim(0, 0.85) - "ящики" ещё лучше читаться будут.</div>

# %% [markdown]
# Явными лидерами являются PS4 и X360 их максимумы близки друг к другу, медиана у них тоже находится близко. Чуть хуже продается XOne, далее идут WII и WiiU.

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Исходя из изменений, можно заметить, что все платформы примерно одинаково популярны, в лидерах находится xone, отстает от всех 3ds.</font>
# </div>

# %%
best_platform = ['ps4']

# %%
best_platform_1 = ['wii']

# %%
best_platform_2 = ['wiiu']

# %%
best_platform_3 = ['3ds']

# %%
best_platform_4 = ['xone']

# %%
df_right_years_platform.query('platform in @best_platform').plot(x='all_sales', y='user_score', kind='scatter')
# Out:
# <AxesSubplot:xlabel='all_sales', ylabel='user_score'>

# %%
df_right_years_platform.query('platform in @best_platform').plot(x='all_sales', y='critic_score', kind='scatter')
# Out:
# <AxesSubplot:xlabel='all_sales', ylabel='critic_score'>

# %% [markdown]
# С ростом оценки растет и количество продаж.

# %%
df_right_years_platform_best = df_right_years_platform.query('platform in @best_platform')

# %%
df_right_years_platform_best['all_sales'].corr(df_right_years_platform_best['critic_score'])
# Out:
# 0.40266141068104083

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Тут всё верно, мы выбрали одну из платформ и проверили линейную зависимость между продажами и оценками пользователей и экспертов.
#
# И вот здесь именно то место, которое упрощает жизнь за счет того, что мы не заполняли пропуски в 'critic_score' и 'user_score'. Если бы это было иначе - перед анализом корреляций надо было бы эти заполненные значения не учитывать (отфильтровывать).
#
# Ввиду же того, что "пропуски" в столбцах с соответствующими оценками мы "заглушками" заполнять не стали (а NaN – значения метод .corr() не учитывает (ссылка на документацию: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.corr.html?highlight=corr#pandas.DataFrame.corr)), то и перед передачей данных в метод .corr() отфильтровывать нам их не пришлось.</div>

# %%
df_right_years_platform_best['all_sales'].corr(df_right_years_platform_best['user_score'])
# Out:
# -0.04013158973738033

# %% [markdown]
# Удивительно, но получилось, что между оценкой критиков и продажами есть средняя связь, а при оценки связи продаж с оценками пользователей связь отсутствует.

# %%
df_right_years_platform.query('platform in @best_platform_1').plot(x='all_sales', y='user_score', kind='scatter')
# Out:
# <AxesSubplot:xlabel='all_sales', ylabel='user_score'>

# %%
df_right_years_platform.query('platform in @best_platform_1').plot(x='all_sales', y='critic_score', kind='scatter')
# Out:
# <AxesSubplot:xlabel='all_sales', ylabel='critic_score'>

# %%
df_right_years_platform_best_1 = df_right_years_platform.query('platform in @best_platform_1')

# %%
df_right_years_platform_best_1['all_sales'].corr(df_right_years_platform_best_1['critic_score'])
# Out:
# nan

# %%
df_right_years_platform_best_1['all_sales'].corr(df_right_years_platform_best_1['user_score'])
# Out:
# 1.0

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Видимо, для Wii оценок очень мало в данном периоде, поэтому получился такой результат.</font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Да, именно!
# </div>

# %%
df_right_years_platform.query('platform in @best_platform_2').plot(x='all_sales', y='user_score', kind='scatter')
# Out:
# <AxesSubplot:xlabel='all_sales', ylabel='user_score'>

# %%
df_right_years_platform.query('platform in @best_platform_2').plot(x='all_sales', y='critic_score', kind='scatter')
# Out:
# <AxesSubplot:xlabel='all_sales', ylabel='critic_score'>

# %%
df_right_years_platform_best_2 = df_right_years_platform.query('platform in @best_platform_2')

# %%
df_right_years_platform_best_2['all_sales'].corr(df_right_years_platform_best_2['user_score'])
# Out:
# 0.4079264698680882

# %%
df_right_years_platform_best_2['all_sales'].corr(df_right_years_platform_best_2['critic_score'])
# Out:
# 0.370201412480884

# %%
df_right_years_platform.query('platform in @best_platform_3').plot(x='all_sales', y='user_score', kind='scatter')
# Out:
# <AxesSubplot:xlabel='all_sales', ylabel='user_score'>

# %%
df_right_years_platform.query('platform in @best_platform_3').plot(x='all_sales', y='critic_score', kind='scatter')
# Out:
# <AxesSubplot:xlabel='all_sales', ylabel='critic_score'>

# %%
df_right_years_platform_best_3 = df_right_years_platform.query('platform in @best_platform_3')

# %%
df_right_years_platform_best_3['all_sales'].corr(df_right_years_platform_best_3['critic_score'])
# Out:
# 0.31411749286905105

# %%
df_right_years_platform_best_3['all_sales'].corr(df_right_years_platform_best_3['user_score'])
# Out:
# 0.2151932747137012

# %%
df_right_years_platform.query('platform in @best_platform_4').plot(x='all_sales', y='user_score', kind='scatter')
# Out:
# <AxesSubplot:xlabel='all_sales', ylabel='user_score'>

# %%
df_right_years_platform.query('platform in @best_platform_4').plot(x='all_sales', y='critic_score', kind='scatter')
# Out:
# <AxesSubplot:xlabel='all_sales', ylabel='critic_score'>

# %%
df_right_years_platform_best_4 = df_right_years_platform.query('platform in @best_platform_4')

# %%
df_right_years_platform_best_4['all_sales'].corr(df_right_years_platform_best_4['critic_score'])
# Out:
# 0.42867694370333226

# %%
df_right_years_platform_best_4['all_sales'].corr(df_right_years_platform_best_4['user_score'])
# Out:
# -0.07038393161528515

# %% [markdown]
# В целом выводы для PS4 такие же и для других платформ. Я увидел почему слабая зависимость, хоть с увеличением оценки и растут продажи но немного. Основная масса продаж находится возле нуля.

# %%
df_right_years.boxplot(column='all_sales', by='genre', figsize=(20,8))
plt.ylim(0, 3)
plt.show()

# %% [markdown]
# Явными лидерами по продажам являются Shooter, Sports, Platform.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Это одно из сложных мест в этом проекте: зачастую студенты делают вывод о выгодности жанра по количеству проданных копий (по этому параметру должны бы выиграть Action-игры), а не по среднему/медианному значению.
# Отлично что ты понимаешь, что общие продажи - это не очень корректная метрика для поиска наиболее прибыльного жанра. За высокими показателями общих продаж может скрываться множество мелких игр с низкими продажами. Или 2-3 звезды и куча провалов.</div>

# %% [markdown]
# 4. Составление портрета пользователя каждого региона

# %%
df_pivot_sales_eu = df_right_years.pivot_table(index='year_of_release', columns='platform', values='eu_sales')

# %%
df_pivot_sales_eu.plot(style='-o', grid=True, figsize=(20,20) )
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %%
df_pivot_sales_jp = df_right_years.pivot_table(index='year_of_release', columns='platform', values='jp_sales')

# %%
df_pivot_sales_jp.plot(style='-o', grid=True, figsize=(20,20) )
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %%
df_pivot_sales_na = df_right_years.pivot_table(index='year_of_release', columns='platform', values='na_sales')

# %%
df_pivot_sales_na.plot(style='-o', grid=True, figsize=(20,20) )
# Out:
# <AxesSubplot:xlabel='year_of_release'>

# %%
main_platform_eu = ['ps4', 'xone', 'wiiu', 'wii', 'pc']

# %%
main_platform_jp = ['3ds', 'psv', 'wiiu', 'ps4', 'ps3']

# %%
main_platform_na = ['ps4', 'xone', 'wiiu', 'wii', '3ds']

# %%
df_right_years_platform_eu = df_right_years.query('platform in @main_platform_eu')

# %%
df_right_years_platform_jp = df_right_years.query('platform in @main_platform_jp')

# %%
df_right_years_platform_na = df_right_years.query('platform in @main_platform_na')

# %%
df_right_years_platform_eu.boxplot(column='eu_sales', by='platform', figsize=(20,10))
plt.ylim(0, 1.5)
plt.show()

# %%
df_right_years_platform_jp.boxplot(column='jp_sales', by='platform', figsize=(20,10))
plt.ylim(0, 1)
plt.show()

# %%
df_right_years_platform_na.boxplot(column='na_sales', by='platform', figsize=(20,10))
plt.ylim(0, 2)
plt.show()

# %% [markdown]
# Везде лидеры примерно одни и те же это XBOX или PS или Wii. Интересная разница между американским рынком и японским в том, что у них продаются больше их родные платформы. У Японии PS, у Америки XBOX. В Европе побеждает PS и в пятерке есть PC.

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'> В Европе явным лидером является Wii, в Японии 3DS, в Америке XOne </font>
# </div>

# %%
df_right_years.boxplot(column='eu_sales', by='genre', figsize=(20,8))
plt.ylim(0, 2)
plt.show()

# %%
df_right_years.boxplot(column='jp_sales', by='genre', figsize=(20,8))
plt.ylim(0, 1)
plt.show()

# %%
df_right_years.boxplot(column='na_sales', by='genre', figsize=(20,8))
plt.ylim(0, 3)
plt.show()

# %% [markdown]
# Топ 3 в Европе и Америке похожи на первом месте Shooter, на втором и третьем отличие в Европе Platform и Racing, а в Америке Platform и Sports, но они прям очень близки по продажам. А в Японии рынок по жанрам сильно отличается. На первом месте Role-Playing, на втором Fighting, на третьем Action.

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'> В Америке и Европе тройка лидеров по жанрам: Shooters, Sports, Platform. В Японии: Role-playing, Puzzle, Fighting. </font>
# </div>

# %%
df_right_years['rating'] = df_right_years['rating'].fillna('TBD')
# Out:
# /tmp/ipykernel_986/3726306867.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_right_years['rating'] = df_right_years['rating'].fillna('TBD')

# %%
ESRB = df_right_years.groupby('rating')['eu_sales','na_sales','jp_sales','other_sales'].sum()
# Out:
# /tmp/ipykernel_986/831825105.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   ESRB = df_right_years.groupby('rating')['eu_sales','na_sales','jp_sales','other_sales'].sum()

# %%
ESRB
# Out:
#         eu_sales  na_sales  jp_sales  other_sales
# rating
# E          58.06     50.74      8.94        15.39
# E10+       26.16     33.23      4.46         7.83
# M          93.44     96.42      8.01        28.67
# T          34.07     38.95     14.78        11.33
# TBD        58.95     64.72     56.90        18.40

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Здесь мы потеряли игры без рейтинга (в самом начале тетрадки у меня был комментарий про то, что мы не должны забыть обработать NaN в 'rating'). Если выполнить (**псевдокод!**): **df_actual['rating'].value_counts(dropna=False)**, то получим, что кроме игр с явными рейтингами (которые ты ниже и анализируешь) есть ещё около тысячи игр без рейтинга. Но продажи именно таких игр могут указать на ключевое различие в регионах.
# Исправь пожалуйста эту ошибку и посмотри - не поменялись ли твои выводы.</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Да, отлично, вижу заполнение пропусков заглушкой TBD. Теперь игры без рейтинга из нашего анализа "не выпадают".
# </div>

# %%
ESRB.plot(kind='bar', figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='rating'>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'> Мне понравилась аббревиатура TBD, как отсутствие оценки/рейтинга, поэтому заменил пропуски на него. Правда очень большое количество неучтенных рейтингов, причем его отсутствие влияет даже в лучшую сторону, например, для Японии.  В Европе и Америке лучше продаются игры для взрослых или для всех. При этом в Японии лучше игры прдаются с рейтингом для подростков. </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Рейтинг ESRB - это американский рейтинг, а в Японии есть своё рейтинговое агентство (CERO). Получается, что Япония страна со своим менталитетом. И твой анализ показывает, что Японцы в игры-то играют не такие, как весь прочий мир и жанры игр там популярны совсем другие, нежели в остальном мире, да и на рейтинги (не своего агентства) не очень то внимание обращают.</div>

# %% [markdown]
# Судя по графику, можно сделать вывод, что влияет на продажи.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Надо описать как влияет.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# (После исправления красного комментария выше) А чем на твой взгляд можно объяснить то, что в Японии лидерами продаж (в количестве копий) являются игры без рейтинга ESRB?</div>

# %% [markdown]
# 5. Проверка гипотез.

# %% [markdown]
# H0: Средние пользовательские рейтинги платформ Xbox One и PC равны

# %% [markdown]
# H1: Средние пользовательские рейтинги платформ Xbox One и PC не равны

# %%
df_right_years['user_score'] = df_right_years['user_score'].fillna(-1)
# Out:
# /tmp/ipykernel_986/2813141018.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_right_years['user_score'] = df_right_years['user_score'].fillna(-1)

# %%
df_right_years['user_score'].unique()
# Out:
# array([-1. ,  8.3,  4.3,  5.7,  5. ,  6.5,  9.1,  6.1,  7.9,  5.4,  8.1,
#         6.4,  3.4,  8.5,  4.8,  4.9,  4.5,  6.2,  8.4,  6.3,  7.7,  9.2,
#         7.6,  8.7,  6.7,  7. ,  4.1,  8.2,  6.8,  5.5,  7.5,  4.4,  5.9,
#         7.2,  6.9,  3.9,  4.2,  3.2,  8.6,  3.1,  9. ,  7.3,  7.4,  6. ,
#         4.7,  7.1,  8.8,  5.1,  6.6,  3. ,  5.8,  2.9,  8.9,  2.7,  8. ,
#         3.5,  7.8,  5.2,  5.6,  4.6,  3.3,  9.3,  4. ,  3.6,  3.7,  2.4,
#         2.8,  5.3,  1.7,  1.6,  3.8,  1.5,  0.7,  2.5,  2. ,  2.1,  0.2,
#         1.9,  1.4,  2.3], dtype=float32)

# %%
df_right_years = df_right_years.query('user_score!=-1')

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# **df_right_years['user_score'].fillna(df_right_years['user_score'].mean())** - а что здесь происходит и самое главное **зачем**?
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Комментарий более неактуален.</div>

# %%
df_right_years['user_score'].unique()
# Out:
# array([8.3, 4.3, 5.7, 5. , 6.5, 9.1, 6.1, 7.9, 5.4, 8.1, 6.4, 3.4, 8.5,
#        4.8, 4.9, 4.5, 6.2, 8.4, 6.3, 7.7, 9.2, 7.6, 8.7, 6.7, 7. , 4.1,
#        8.2, 6.8, 5.5, 7.5, 4.4, 5.9, 7.2, 6.9, 3.9, 4.2, 3.2, 8.6, 3.1,
#        9. , 7.3, 7.4, 6. , 4.7, 7.1, 8.8, 5.1, 6.6, 3. , 5.8, 2.9, 8.9,
#        2.7, 8. , 3.5, 7.8, 5.2, 5.6, 4.6, 3.3, 9.3, 4. , 3.6, 3.7, 2.4,
#        2.8, 5.3, 1.7, 1.6, 3.8, 1.5, 0.7, 2.5, 2. , 2.1, 0.2, 1.9, 1.4,
#        2.3], dtype=float32)

# %%
xone = ['xone']

# %%
pc = ['pc']

# %%
df_xone=df_right_years.query('platform in @xone')

# %%
df_pc=df_right_years.query('platform in @pc')

# %%
df_xone_score = df_xone['user_score']

# %%
df_pc_score = df_pc['user_score']

# %%
alpha = 0.01# ваш код: задайте критический уровень статистической значимости

results = st.ttest_ind(
    df_xone_score, 
    df_pc_score,
    equal_var=False) # ваш код: проверьте гипотезу о равенстве средних двух независимых совокупностей


print('p-значение:', results.pvalue)

if results.pvalue < alpha: 
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.1160154559677266
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# H0: Средние пользовательские рейтинги жанров action и sports равны

# %% [markdown]
# H1: Средние пользовательские рейтинги жанров action и sports не равны

# %%
df_right_years['genre'].unique()
# Out:
# array(['Action', 'Sports', 'Shooter', 'Role-Playing', 'Racing',
#        'Platform', 'Simulation', 'Fighting', 'Misc', 'Adventure',
#        'Puzzle', 'Strategy'], dtype=object)

# %%
action = ['Action']

# %%
sports = ['Sports']

# %%
df_action=df_right_years.query('genre in @action')

# %%
df_sports=df_right_years.query('genre in @sports')

# %%
df_action_score = df_action['user_score']

# %%
df_sports_score = df_sports['user_score']

# %%
alpha = 0.01# ваш код: задайте критический уровень статистической значимости

results = st.ttest_ind(
    df_action_score, 
    df_sports_score,
    equal_var=False) # ваш код: проверьте гипотезу о равенстве средних двух независимых совокупностей


print('p-значение:', results.pvalue)

if results.pvalue < alpha: 
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 1.1825639880196408e-14
# Отвергаем нулевую гипотезу

# %% [markdown]
# В обоих случаях средние получились равны.

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'> Из проверок гипотез получилось следующее: У нас нет оснований утверждать, что средние пользовательские рейтинги платформ Xbox One и PC значимо различаются, при этом мы можем утверждать, что средние пользовательские рейтинги жанров action и sports значимо отличаются </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# +</div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Нельзя сделать вывод, что тест "подтвердил" одну из гипотез (в статистике гипотезы подтвердить невозможно) или "подтвердил" равенство/неравенство (можно говорить только о статистически (не)значимом различии). Например так: «У нас нет оснований утверждать, что средние пользовательские рейтинги платформ Xbox One и PC значимо различаются».</div>

# %% [markdown]
# Для проверки гипотез использовал гипотезу о равенстве средних двух генеральных совокупностей. Так как нам доступна генеральная совокупность и мы из нее берем данные уже о двух других совокупностях. Плюс нужно понять равны ли средние значения в них, также эти две совокупности не зависят друг от друга. По этим критериям и сделал выбор в сторону scipy.stats.ttest_ind(), также не было уверенности, что генеральные совокупности одинаковы по размеру и дисперсии могут быть разные, поэтому задал equal_var = False.

# %% [markdown]
# 6. Вывод

# %% [markdown]
# Вывод: Американский и Европейский рынок схожи по продажам и по платформам, которые чаще всего покупают, также жанры в этих регионах похожи. А вот Японский рынок очень отличается по данным параметрам от остального мира. Также было выяснено, что оценки слабо влияют на продажи или не влияют вовсе. Для выбора игры на Американском и Европейских рынках нужно, чтобы она выпускалась на платформе PS4 для Европы и XBOX для Америки и была в жанре Shooter. Для Японского рынка важно, чтобы игра выпускалась на платформе PS, а жанр был Role-playing.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Давай представим вполне себе реалистичный сценарий: после выполнения анализа ты готовишь презентацию для топ-менеджмента компании и получаешь приглашение на совет директоров для рассказа и представления своих выводов. Ты ровно эти выводы с собой понесешь? Достаточно ли они детальны, описывают ли они все аспекты (задачи из брифа), которые мы должны были обнаружить, интерпретировать и описать?</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>
#     Выводы:
#
#         1. Одним из главных моментов, на которые нужно обратить внимание это то, в каком регионе планируются продажи. Поэтому первым делом нужно определиться с регионом, для каждого из них разная картина по успешности продаж игр.
#
#         2. Для успеха продаж в Европе игра должна выпускаться на платформе Wii, в жанре Shooters, в возрастном диапазоне для взрослых по рейтингу ESRB.
#
#         3. Для успеха продаж в Японии игра должна выпускаться на платформе 3DS, в жанре Role-playing, в возрастном диапазоне для подростков по рейтингу ESRB или вообще без рейтинга.
#
#         4. Для успеха продаж в Америке игра должна выпускаться на платформе  Xone, в жанре Shooters, в возрастном диапазоне для взрослых по рейтингу ESRB.
#
#         5. Оценки критиков и пользователей не влияют на продажи.
#
#         6. Если игра будет выпускаться по миру, то лучшим жанром для игры будет Shooter, платформа XOne для возрастной категории взрослые или без данного рейтинга. Либо можно сконцентрировать силы на платформе 3DS, продажи которой по миру растут.
#
#         7. Также было выяснено, что нужно учитывать тот факт, что платформы в среднем находятся на рынке 7 с половиной лет.
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Отлично, принимаю вывод, Дмитрий</div>

# %% [markdown]
# # Результат ревью:
#
# Я отмечаю высокий уровень твоей программистской подготовки. Ты используешь продвинутые концепции языка Python и библиотеки pandas. Всё это в целом упрощает твой код и одновременно показывает твой уровень владения инструментами.
#
# Ты умело применяешь графические библиотеки (matplotlib), выбираешь для визуализации ровно те типы графиков, которые нужны. Если ещё поработать над тем, чтобы все оси были подписаны и графики имели понятные названия, то будет просто отлично.
#
# С комментированием никаких проблем нет. Твоих объяснений достаточно для понимания твоими коллегами хода мыслей. Ссылки из брифа проекта в нужных местах также помогают следовать за развитием событий и дают полную информацию касаемо того, что будет происходить в том или ином разделе проекта.
#
# Зелёным цветом я отметил и прокомментировал удачные и элегантные решения, на которые ты можешь опираться в будущих проектах.
#
# Жёлтым цветом я выделил то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас.
#
# Однако есть принципиальные моменты, которые не позволяют мне принять твой проект в его нынешнем состоянии:
#
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# 1. Одна из задач этого проекта (согласно брифа): 1. Объясните, почему заполнили пропуски определённым образом или почему не стали это делать, 2. Опишите причины, которые могли привести к пропускам 3. Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите, как его обработать. Нужен твой комментарий, касающийся природы пропусков в столбце с рейтингами, а именно, может ли быть какая-то связь с тем, что в столбце с рейтингами >40% пропусков и тем, что эти оценки (рейтинги) выставляет **именно Американское рейтинговое агентство?
#
# 2. Любая предобработка данных предполагает поиск и анализ дубликатов. В твоём разделе EDA (== Exploratory Data Analysis) подобной важной составляющей нет. После поиска и обнаружения - опиши как их планируешь и планируешь ли обрабатывать?
#
# 3. Для анализа взят слишком большой интервал. Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал.
#
# 4. Мы "потеряли" игры без рейтинга. Кроме игр с явными рейтингами (которые ты анализируешь) есть ещё около тысячи игр без рейтинга. Но продажи именно таких игр могут указать на ключевое различие в регионах.
#
# 5. В разделе проверки гипотез, ты на проверку передаешь кроме "реальных оценок пользователей" ещё и данные содержащие NaN и заполненные руками значения.
#
# 6. Нельзя сделать вывод, что что наш тест "подтвердил" одну из гипотез (в статистике гипотезы подтвердить невозможно) или "подтвердил" равенство/неравенство (можно говорить только о статистически (не)значимом различии).
#
# 7. Финальный вывод в таком виде - это не то, что менеджмент компании ждет от аналитика данных. Профессионал должен предоставить точные, четкие, полные и корректные **прогнозы и рекомендации**, которые помогут компании победить в конкурентной борьбе на высоко конкурентном рынке продаж компьютерных игр. Вывод же, завершающий твой рабочий проект, увы, бесполезен для генерального директора твоей компании. Он ему ничем не поможет. Здесь, в финальном выводе требуется максимально подробно описать что ты предлагаешь сделать в 2017 году, для того, чтобы твоя компания победила конкурентов.</div>
#
# Эти 7 моментов требуют твоего внимания. Комментарии по ним помечены красным цветом.
#
# Подводя итог: хорошая, надежная работа на самом-то деле, молодец! Есть несколько моментов к исправлению, но уверен, что они не вызовут у тебя сложностей. После доработки обязательно проверь комментарии и выводы. Их нужно будет скорректировать. Жду доработанную версию проекта на повторное ревью.
